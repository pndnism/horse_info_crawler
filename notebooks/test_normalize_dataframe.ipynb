# %%
import pandas as pd
import re
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_pickle("../tests/race/parser/data/test_race_info_dataframe.pkl")

# %%
list(df["賞金(万円)"])
# Out:
# ['25.0', '7.0', '4.0', '2.5', '1.5', '', '', '']

# %%
df["age"] = df["性齢"].str.extract("(\d+)")

# %%
df["horse_weight"] = df["馬体重"].str.extract("(\d+)")

# %%
df["horse_weight_diff"] = df["馬体重"].str.extract("\((\W*\d+)\)")

# %%
re.findall("\((\W*\d+)\)","484(0)")
# Out:
# ['0']

# %%
df
# Out:
#   着順 枠番 馬番         馬名  性齢  斤量    騎手     タイム   着差 ﾀｲﾑ指数   通過    上り     単勝 人気  \
# 0  1  5  5     ベッサラビア  牡3  56   関本淳  1:15.2             1-1  39.0    1.6  1
# 1  2  2  2   サフランハピネス  牝3  50  関本玲花  1:16.2    6        5-4  38.6   13.5  5
# 2  3  6  6  クリノビックスター  牡3  56   岩本怜  1:16.3   クビ        7-6  38.2    3.7  2
# 3  4  3  3  カーヴィーレーザー  セ3  56   木村暁  1:16.5    1        3-3  39.7   16.7  6
# 4  5  4  4   ベルベストスター  牡3  56   村上忍  1:17.7    7        2-2  41.3    7.6  3
# 5  6  1  1   オウケノヒメミコ  牝6  54   大坪慎  1:17.9    1        8-8  39.3  114.4  8
# 6  7  8  8   プチジュラシック  牡3  56  山本政聡  1:18.8    6        6-7  41.1   29.1  7
# 7  8  7  7  シャイニードラード  牡5  56   鈴木祐  1:18.9  3/4        4-5  42.0   11.9  4
#
#         馬体重 調教ﾀｲﾑ 厩舎ｺﾒﾝﾄ 備考      調教師        馬主 賞金(万円) sex age horse_weight  \
# 0  484(+22)                  [地]斉藤雄一      森田藤治   25.0   牡   3          484
# 1   424(-3)                  [地]佐藤祐司       森田徹    7.0   牝   3          424
# ...
